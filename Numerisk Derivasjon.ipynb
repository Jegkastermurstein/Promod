# %% [markdown]
# # Numerisk matematikk 1
# ## Numerisk derivasjon
#
# (a)
#
# En sekant er en linje som går gjennom hvertfall 2 punkter på en graf. Stigningstallet K kan vi finne ved å bruke definisjonen av den deriverte fordi når vi deriverer finner vi stigningstallet.
#
# (b)
# En tangent er linje som treffer linja på et puunkt på en kurvete graf. Stigningstallet til tangenten er momentanfarten som du kan finne ved å bruke denne formelen her
#
# ![image.png](attachment:image.png)

# %% [markdown]
# (c)
# Derivasjon er en operasjon i matte som brukes for å studere endringer i ulike verdier.
#
#
#
# Kilde:
# - Simen littorin Birkeland

# %%
(d)


Forskjellen mellom Newtons kvotien og definisjonen av den deriverte er når h går imot infinitesimal


def f(x):
    return 4*x**2+4

def deriv(x, h, f):
    return
# Out:
#   File "<ipython-input-1-7ec03ebca3d2>", line 4
#     Forskjellen mellom Newtons kvotien og definisjonen av den deriverte er når h går imot infinitesimal
#                      ^
# SyntaxError: invalid syntax

# %%
from pylab import *



data = loadtxt("Presset.txt", skiprows=1, delimiter=",")
print(data)

tid = data[:, 0]
høyde = data[:, 2]

Speed = [0, ]


for i in range(0, 47):
    fart = (høyde[i+1]-høyde[i])/(tid[i+1]-tid[i])
    i = i+1
    Speed.append(fart)
    
print("Farten er", fart, "m/s")
plot(tid, høyde)
title("Høyde ved tid")
xlabel("Tid. (s)")
ylabel("Høyde. (M)")
show()



plot(tid, Speed)
title("Farten per sekund")
xlabel("Tid, (S)")
ylabel("Høyde, (M)")
show()
# Out:
# [[ 0.00000000e+00  9.96078110e+02  0.00000000e+00  5.08932500e-01
#   -1.26548328e-03]
#  [ 1.01786500e+00  9.96078262e+02 -1.28809114e-03  1.52677650e+00
#    5.06214294e-03]
#  [ 2.03568800e+00  9.96077652e+02  3.86427437e-03  2.54448850e+00
#    4.43034344e-03]
#  [ 3.05328900e+00  9.96077118e+02  8.37259629e-03  3.56214050e+00
#    6.89801104e-02]
#  [ 4.07099200e+00  9.96068802e+02  7.85738615e-02  4.62180400e+00
#    8.24342199e-02]
#  [ 5.17261600e+00  9.96058044e+02  1.69385377e-01  6.11502300e+00
#    8.11562593e-02]
#  [ 7.05743000e+00  9.96039925e+02  3.22349830e-01  7.99999700e+00
#    1.14626471e-01]
#  [ 8.94256400e+00  9.96014328e+02  5.38436088e-01  9.88521200e+00
#    1.12056707e-01]
#  [ 1.08278600e+01  9.95989304e+02  7.49696149e-01  1.17702735e+01
#    1.15675055e-01]
#  [ 1.27126870e+01  9.95963478e+02  9.67723616e-01  1.36551020e+01
#    1.14139476e-01]
#  [ 1.45975170e+01  9.95937996e+02  1.18285712e+00  1.55401105e+01
#    1.10874258e-01]
# ...

# %%
data = loadtxt("Acceleration.txt", skiprows=1, delimiter=",")
print(data)

tid = data[:, 0]
akselerasjon = data[:, 1]


plot(tid, akselerasjon)
# Out:
# [[ 0.00000000e+00  7.35428676e-01]
#  [ 4.99850000e-02 -6.81584435e-01]
#  [ 9.99690000e-02 -1.34442808e-01]
#  ...
#  [ 8.89719549e+01  2.02579944e-01]
#  [ 8.90219389e+01  2.38037693e-01]
#  [ 8.90719229e+01 -8.10189616e-01]]
